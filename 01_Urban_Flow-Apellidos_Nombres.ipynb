# %% [markdown]
# # Trabajo Práctico Integrador — Urban Flow
#
# **Sprint 1** · Git: `main` ← `Sprint_1` ← `feature/katherine` / `feature/joaquin` / `feature/emilce` / `feature/camardelli`
#
# **Integrantes:**
# - Katherine
# - Joaquín
# - Camardelli
# - Emi
#
# Notebook único de entrega. Cada bloque llama al módulo en `urban_flow/ejercicio_XX.py` (ver README y comentarios en cada archivo).

# %%
# title: Importaciones (antes del Ejercicio 01; sin otras celdas de
# import antes de este bloque)
from __future__ import annotations

import re
import subprocess
import urllib.request
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

desactivar_git_push = True

# %% [markdown]
# ## Ejercicio 01
#
# Módulo: `urban_flow/ejercicio_01.py` · **Katherine**
#
# La celda siguiente crea la estructura `urban_flow/data/` (raw, interim,
# processed, interim/plots) y deja el repositorio en la rama **`Sprint_1`**,
# como pide la consigna.

# %%
# title: Invocación Ejercicio 01
from urban_flow import ejercicio_01

ejercicio_01.run()
# Out:
# Ej. 01 listo — carpetas bajo C:\Users\Usuario\Documents\HerramientasDelSoftware\urban_flow\data

# %% [markdown]
# ## Ejercicio 02
#
# Módulo: `urban_flow/ejercicio_02.py` · **Joaquín**

# %%
# title: Invocación Ejercicio 02
from urban_flow import ejercicio_02

df_raw = ejercicio_02.run()
df_raw

# %% [markdown]
# ## Ejercicio 03
#
# Módulo: `urban_flow/ejercicio_03.py` · **Emi**

# %%
# title: Invocación Ejercicio 03
from urban_flow import ejercicio_03

df_limpio = ejercicio_03.run(df_raw)
df_limpio

# %% [markdown]
# ## Ejercicio 04
#
# Módulo: `urban_flow/ejercicio_04.py` · **Camardelli** · clase `FineAnalyzer`

# %%
# title: Definición de FineAnalyzer (importar desde el módulo)
from urban_flow.ejercicio_04 import FineAnalyzer

# %%
# title: Instancia FineAnalyzer
analyzer = FineAnalyzer(df_limpio)

# %%
# title: ranking_patentes
analyzer.ranking_patentes()

# %%
# title: ranking_horarios
analyzer.ranking_horarios()

# %%
# title: promedio_exceso
analyzer.promedio_exceso()

# %%
# title: promedio_exceso_real
analyzer.promedio_exceso_real()

# %%
# title: multas_por_ubicacion
analyzer.multas_por_ubicacion()

# %% [markdown]
# ## Punto 05
#
# Módulo: `urban_flow/ejercicio_05.py` · **Katherine**

# %%
# title: Invocación Punto 05
from urban_flow import ejercicio_05

ejercicio_05.run(df_limpio)

# %% [markdown]
# ## Punto 06
#
# Módulo: `urban_flow/ejercicio_06.py` · **Joaquín**

# %%
# title: Invocación Punto 06
from urban_flow import ejercicio_06

ejercicio_06.run(df_limpio)

# %% [markdown]
# ## Punto 07
#
# Texto: `urban_flow/ejercicio_07_conclusion.md` · **Camardelli**
#
# (Copiar aquí la conclusión final o redactar en esta celda.)
